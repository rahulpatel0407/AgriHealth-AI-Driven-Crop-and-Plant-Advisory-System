# %% [markdown]
# # Training Notebook
#
# Baseline training workflow for PlantVillage dataset.

# %%
import importlib
torch = importlib.import_module("torch")
models = importlib.import_module("torchvision.models")

model = models.resnet50(weights=None)
model
